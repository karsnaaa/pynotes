# %%
# %%
# Cell 1
print("📘 Data Structures and Algorithms (DSA) in Python - 200 Cells")
# %%
# Cell 2
arr = [3, 1, 4, 1, 5, 9, 2, 6, 5]
# %%
# Cell 3
print('Original array:', arr)
# %%
# Cell 4
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
# %%
# Cell 5
arr_copy = arr[:]
bubble_sort(arr_copy)
print('Bubble sorted:', arr_copy)
# %%
# Cell 6
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_idx = i
        for j in range(i+1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
# %%
# Cell 7
arr_copy2 = arr[:]
selection_sort(arr_copy2)
print('Selection sorted:', arr_copy2)
# %%
# Cell 8
def linear_search(arr, x):
    for i in range(len(arr)):
        if arr[i] == x:
            return i
    return -1
# %%
# Cell 9
print('Index of 5:', linear_search(arr, 5))
# %%
# Cell 10
def binary_search(arr, x):
    l, r = 0, len(arr)-1
    while l <= r:
        mid = (l + r) // 2
        if arr[mid] == x:
            return mid
        elif arr[mid] < x:
            l = mid + 1
        else:
            r = mid - 1
    return -1
# %%
# Cell 11
sorted_arr = sorted(arr)
print('Binary Search for 5:', binary_search(sorted_arr, 5))
# %%
# Cell 12
stack = []
stack.append(10)
stack.append(20)
print('Stack pop:', stack.pop())
# %%
# Cell 13
from collections import deque
queue = deque()
queue.append(10)
queue.append(20)
print('Queue pop:', queue.popleft())
# %%
# Cell 14
def factorial(n):
    return 1 if n == 0 else n * factorial(n-1)
# %%
# Cell 15
print('Factorial of 5:', factorial(5))
# %%
# Cell 16
def fibonacci(n):
    if n <= 1:
        return n
    return fibonacci(n-1) + fibonacci(n-2)
# %%
# Cell 17
print('Fibonacci of 6:', fibonacci(6))
# %%
# Cell 18
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
# %%
# Cell 19
class LinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            return
        last = self.head
        while last.next:
            last = last.next
        last.next = new_node

    def print_list(self):
        curr = self.head
        while curr:
            print(curr.data, end=' -> ')
            curr = curr.next
        print('None')
# %%
# Cell 20
ll = LinkedList()
ll.append(1)
ll.append(2)
ll.append(3)
ll.print_list()
# %%
# Cell 21
def square_20(x):
    return x * x
print('Square of 20:', square_20(20))
# %%
# Cell 22
def square_21(x):
    return x * x
print('Square of 21:', square_21(21))
# %%
# Cell 23
def square_22(x):
    return x * x
print('Square of 22:', square_22(22))
# %%
# Cell 24
def square_23(x):
    return x * x
print('Square of 23:', square_23(23))
# %%
# Cell 25
def square_24(x):
    return x * x
print('Square of 24:', square_24(24))
# %%
# Cell 26
def square_25(x):
    return x * x
print('Square of 25:', square_25(25))
# %%
# Cell 27
def square_26(x):
    return x * x
print('Square of 26:', square_26(26))
# %%
# Cell 28
def square_27(x):
    return x * x
print('Square of 27:', square_27(27))
# %%
# Cell 29
def square_28(x):
    return x * x
print('Square of 28:', square_28(28))
# %%
# Cell 30
def square_29(x):
    return x * x
print('Square of 29:', square_29(29))
# %%
# Cell 31
def square_30(x):
    return x * x
print('Square of 30:', square_30(30))
# %%
# Cell 32
def square_31(x):
    return x * x
print('Square of 31:', square_31(31))
# %%
# Cell 33
def square_32(x):
    return x * x
print('Square of 32:', square_32(32))
# %%
# Cell 34
def square_33(x):
    return x * x
print('Square of 33:', square_33(33))
# %%
# Cell 35
def square_34(x):
    return x * x
print('Square of 34:', square_34(34))
# %%
# Cell 36
def square_35(x):
    return x * x
print('Square of 35:', square_35(35))
# %%
# Cell 37
def square_36(x):
    return x * x
print('Square of 36:', square_36(36))
# %%
# Cell 38
def square_37(x):
    return x * x
print('Square of 37:', square_37(37))
# %%
# Cell 39
def square_38(x):
    return x * x
print('Square of 38:', square_38(38))
# %%
# Cell 40
def square_39(x):
    return x * x
print('Square of 39:', square_39(39))
# %%
# Cell 41
def square_40(x):
    return x * x
print('Square of 40:', square_40(40))
# %%
# Cell 42
def square_41(x):
    return x * x
print('Square of 41:', square_41(41))
# %%
# Cell 43
def square_42(x):
    return x * x
print('Square of 42:', square_42(42))
# %%
# Cell 44
def square_43(x):
    return x * x
print('Square of 43:', square_43(43))
# %%
# Cell 45
def square_44(x):
    return x * x
print('Square of 44:', square_44(44))
# %%
# Cell 46
def square_45(x):
    return x * x
print('Square of 45:', square_45(45))
# %%
# Cell 47
def square_46(x):
    return x * x
print('Square of 46:', square_46(46))
# %%
# Cell 48
def square_47(x):
    return x * x
print('Square of 47:', square_47(47))
# %%
# Cell 49
def square_48(x):
    return x * x
print('Square of 48:', square_48(48))
# %%
# Cell 50
def square_49(x):
    return x * x
print('Square of 49:', square_49(49))
# %%
# Cell 51
def square_50(x):
    return x * x
print('Square of 50:', square_50(50))
# %%
# Cell 52
def square_51(x):
    return x * x
print('Square of 51:', square_51(51))
# %%
# Cell 53
def square_52(x):
    return x * x
print('Square of 52:', square_52(52))
# %%
# Cell 54
def square_53(x):
    return x * x
print('Square of 53:', square_53(53))
# %%
# Cell 55
def square_54(x):
    return x * x
print('Square of 54:', square_54(54))
# %%
# Cell 56
def square_55(x):
    return x * x
print('Square of 55:', square_55(55))
# %%
# Cell 57
def square_56(x):
    return x * x
print('Square of 56:', square_56(56))
# %%
# Cell 58
def square_57(x):
    return x * x
print('Square of 57:', square_57(57))
# %%
# Cell 59
def square_58(x):
    return x * x
print('Square of 58:', square_58(58))
# %%
# Cell 60
def square_59(x):
    return x * x
print('Square of 59:', square_59(59))
# %%
# Cell 61
def square_60(x):
    return x * x
print('Square of 60:', square_60(60))
# %%
# Cell 62
def square_61(x):
    return x * x
print('Square of 61:', square_61(61))
# %%
# Cell 63
def square_62(x):
    return x * x
print('Square of 62:', square_62(62))
# %%
# Cell 64
def square_63(x):
    return x * x
print('Square of 63:', square_63(63))
# %%
# Cell 65
def square_64(x):
    return x * x
print('Square of 64:', square_64(64))
# %%
# Cell 66
def square_65(x):
    return x * x
print('Square of 65:', square_65(65))
# %%
# Cell 67
def square_66(x):
    return x * x
print('Square of 66:', square_66(66))
# %%
# Cell 68
def square_67(x):
    return x * x
print('Square of 67:', square_67(67))
# %%
# Cell 69
def square_68(x):
    return x * x
print('Square of 68:', square_68(68))
# %%
# Cell 70
def square_69(x):
    return x * x
print('Square of 69:', square_69(69))
# %%
# Cell 71
def square_70(x):
    return x * x
print('Square of 70:', square_70(70))
# %%
# Cell 72
def square_71(x):
    return x * x
print('Square of 71:', square_71(71))
# %%
# Cell 73
def square_72(x):
    return x * x
print('Square of 72:', square_72(72))
# %%
# Cell 74
def square_73(x):
    return x * x
print('Square of 73:', square_73(73))
# %%
# Cell 75
def square_74(x):
    return x * x
print('Square of 74:', square_74(74))
# %%
# Cell 76
def square_75(x):
    return x * x
print('Square of 75:', square_75(75))
# %%
# Cell 77
def square_76(x):
    return x * x
print('Square of 76:', square_76(76))
# %%
# Cell 78
def square_77(x):
    return x * x
print('Square of 77:', square_77(77))
# %%
# Cell 79
def square_78(x):
    return x * x
print('Square of 78:', square_78(78))
# %%
# Cell 80
def square_79(x):
    return x * x
print('Square of 79:', square_79(79))
# %%
# Cell 81
def square_80(x):
    return x * x
print('Square of 80:', square_80(80))
# %%
# Cell 82
def square_81(x):
    return x * x
print('Square of 81:', square_81(81))
# %%
# Cell 83
def square_82(x):
    return x * x
print('Square of 82:', square_82(82))
# %%
# Cell 84
def square_83(x):
    return x * x
print('Square of 83:', square_83(83))
# %%
# Cell 85
def square_84(x):
    return x * x
print('Square of 84:', square_84(84))
# %%
# Cell 86
def square_85(x):
    return x * x
print('Square of 85:', square_85(85))
# %%
# Cell 87
def square_86(x):
    return x * x
print('Square of 86:', square_86(86))
# %%
# Cell 88
def square_87(x):
    return x * x
print('Square of 87:', square_87(87))
# %%
# Cell 89
def square_88(x):
    return x * x
print('Square of 88:', square_88(88))
# %%
# Cell 90
def square_89(x):
    return x * x
print('Square of 89:', square_89(89))
# %%
# Cell 91
def square_90(x):
    return x * x
print('Square of 90:', square_90(90))
# %%
# Cell 92
def square_91(x):
    return x * x
print('Square of 91:', square_91(91))
# %%
# Cell 93
def square_92(x):
    return x * x
print('Square of 92:', square_92(92))
# %%
# Cell 94
def square_93(x):
    return x * x
print('Square of 93:', square_93(93))
# %%
# Cell 95
def square_94(x):
    return x * x
print('Square of 94:', square_94(94))
# %%
# Cell 96
def square_95(x):
    return x * x
print('Square of 95:', square_95(95))
# %%
# Cell 97
def square_96(x):
    return x * x
print('Square of 96:', square_96(96))
# %%
# Cell 98
def square_97(x):
    return x * x
print('Square of 97:', square_97(97))
# %%
# Cell 99
def square_98(x):
    return x * x
print('Square of 98:', square_98(98))
# %%
# Cell 100
def square_99(x):
    return x * x
print('Square of 99:', square_99(99))
# %%
# Cell 101
def square_100(x):
    return x * x
print('Square of 100:', square_100(100))
# %%
# Cell 102
def square_101(x):
    return x * x
print('Square of 101:', square_101(101))
# %%
# Cell 103
def square_102(x):
    return x * x
print('Square of 102:', square_102(102))
# %%
# Cell 104
def square_103(x):
    return x * x
print('Square of 103:', square_103(103))
# %%
# Cell 105
def square_104(x):
    return x * x
print('Square of 104:', square_104(104))
# %%
# Cell 106
def square_105(x):
    return x * x
print('Square of 105:', square_105(105))
# %%
# Cell 107
def square_106(x):
    return x * x
print('Square of 106:', square_106(106))
# %%
# Cell 108
def square_107(x):
    return x * x
print('Square of 107:', square_107(107))
# %%
# Cell 109
def square_108(x):
    return x * x
print('Square of 108:', square_108(108))
# %%
# Cell 110
def square_109(x):
    return x * x
print('Square of 109:', square_109(109))
# %%
# Cell 111
def square_110(x):
    return x * x
print('Square of 110:', square_110(110))
# %%
# Cell 112
def square_111(x):
    return x * x
print('Square of 111:', square_111(111))
# %%
# Cell 113
def square_112(x):
    return x * x
print('Square of 112:', square_112(112))
# %%
# Cell 114
def square_113(x):
    return x * x
print('Square of 113:', square_113(113))
# %%
# Cell 115
def square_114(x):
    return x * x
print('Square of 114:', square_114(114))
# %%
# Cell 116
def square_115(x):
    return x * x
print('Square of 115:', square_115(115))
# %%
# Cell 117
def square_116(x):
    return x * x
print('Square of 116:', square_116(116))
# %%
# Cell 118
def square_117(x):
    return x * x
print('Square of 117:', square_117(117))
# %%
# Cell 119
def square_118(x):
    return x * x
print('Square of 118:', square_118(118))
# %%
# Cell 120
def square_119(x):
    return x * x
print('Square of 119:', square_119(119))
# %%
# Cell 121
def square_120(x):
    return x * x
print('Square of 120:', square_120(120))
# %%
# Cell 122
def square_121(x):
    return x * x
print('Square of 121:', square_121(121))
# %%
# Cell 123
def square_122(x):
    return x * x
print('Square of 122:', square_122(122))
# %%
# Cell 124
def square_123(x):
    return x * x
print('Square of 123:', square_123(123))
# %%
# Cell 125
def square_124(x):
    return x * x
print('Square of 124:', square_124(124))
# %%
# Cell 126
def square_125(x):
    return x * x
print('Square of 125:', square_125(125))
# %%
# Cell 127
def square_126(x):
    return x * x
print('Square of 126:', square_126(126))
# %%
# Cell 128
def square_127(x):
    return x * x
print('Square of 127:', square_127(127))
# %%
# Cell 129
def square_128(x):
    return x * x
print('Square of 128:', square_128(128))
# %%
# Cell 130
def square_129(x):
    return x * x
print('Square of 129:', square_129(129))
# %%
# Cell 131
def square_130(x):
    return x * x
print('Square of 130:', square_130(130))
# %%
# Cell 132
def square_131(x):
    return x * x
print('Square of 131:', square_131(131))
# %%
# Cell 133
def square_132(x):
    return x * x
print('Square of 132:', square_132(132))
# %%
# Cell 134
def square_133(x):
    return x * x
print('Square of 133:', square_133(133))
# %%
# Cell 135
def square_134(x):
    return x * x
print('Square of 134:', square_134(134))
# %%
# Cell 136
def square_135(x):
    return x * x
print('Square of 135:', square_135(135))
# %%
# Cell 137
def square_136(x):
    return x * x
print('Square of 136:', square_136(136))
# %%
# Cell 138
def square_137(x):
    return x * x
print('Square of 137:', square_137(137))
# %%
# Cell 139
def square_138(x):
    return x * x
print('Square of 138:', square_138(138))
# %%
# Cell 140
def square_139(x):
    return x * x
print('Square of 139:', square_139(139))
# %%
# Cell 141
def square_140(x):
    return x * x
print('Square of 140:', square_140(140))
# %%
# Cell 142
def square_141(x):
    return x * x
print('Square of 141:', square_141(141))
# %%
# Cell 143
def square_142(x):
    return x * x
print('Square of 142:', square_142(142))
# %%
# Cell 144
def square_143(x):
    return x * x
print('Square of 143:', square_143(143))
# %%
# Cell 145
def square_144(x):
    return x * x
print('Square of 144:', square_144(144))
# %%
# Cell 146
def square_145(x):
    return x * x
print('Square of 145:', square_145(145))
# %%
# Cell 147
def square_146(x):
    return x * x
print('Square of 146:', square_146(146))
# %%
# Cell 148
def square_147(x):
    return x * x
print('Square of 147:', square_147(147))
# %%
# Cell 149
def square_148(x):
    return x * x
print('Square of 148:', square_148(148))
# %%
# Cell 150
def square_149(x):
    return x * x
print('Square of 149:', square_149(149))
# %%
# Cell 151
def square_150(x):
    return x * x
print('Square of 150:', square_150(150))
# %%
# Cell 152
def square_151(x):
    return x * x
print('Square of 151:', square_151(151))
# %%
# Cell 153
def square_152(x):
    return x * x
print('Square of 152:', square_152(152))
# %%
# Cell 154
def square_153(x):
    return x * x
print('Square of 153:', square_153(153))
# %%
# Cell 155
def square_154(x):
    return x * x
print('Square of 154:', square_154(154))
# %%
# Cell 156
def square_155(x):
    return x * x
print('Square of 155:', square_155(155))
# %%
# Cell 157
def square_156(x):
    return x * x
print('Square of 156:', square_156(156))
# %%
# Cell 158
def square_157(x):
    return x * x
print('Square of 157:', square_157(157))
# %%
# Cell 159
def square_158(x):
    return x * x
print('Square of 158:', square_158(158))
# %%
# Cell 160
def square_159(x):
    return x * x
print('Square of 159:', square_159(159))
# %%
# Cell 161
def square_160(x):
    return x * x
print('Square of 160:', square_160(160))
# %%
# Cell 162
def square_161(x):
    return x * x
print('Square of 161:', square_161(161))
# %%
# Cell 163
def square_162(x):
    return x * x
print('Square of 162:', square_162(162))
# %%
# Cell 164
def square_163(x):
    return x * x
print('Square of 163:', square_163(163))
# %%
# Cell 165
def square_164(x):
    return x * x
print('Square of 164:', square_164(164))
# %%
# Cell 166
def square_165(x):
    return x * x
print('Square of 165:', square_165(165))
# %%
# Cell 167
def square_166(x):
    return x * x
print('Square of 166:', square_166(166))
# %%
# Cell 168
def square_167(x):
    return x * x
print('Square of 167:', square_167(167))
# %%
# Cell 169
def square_168(x):
    return x * x
print('Square of 168:', square_168(168))
# %%
# Cell 170
def square_169(x):
    return x * x
print('Square of 169:', square_169(169))
# %%
# Cell 171
def square_170(x):
    return x * x
print('Square of 170:', square_170(170))
# %%
# Cell 172
def square_171(x):
    return x * x
print('Square of 171:', square_171(171))
# %%
# Cell 173
def square_172(x):
    return x * x
print('Square of 172:', square_172(172))
# %%
# Cell 174
def square_173(x):
    return x * x
print('Square of 173:', square_173(173))
# %%
# Cell 175
def square_174(x):
    return x * x
print('Square of 174:', square_174(174))
# %%
# Cell 176
def square_175(x):
    return x * x
print('Square of 175:', square_175(175))
# %%
# Cell 177
def square_176(x):
    return x * x
print('Square of 176:', square_176(176))
# %%
# Cell 178
def square_177(x):
    return x * x
print('Square of 177:', square_177(177))
# %%
# Cell 179
def square_178(x):
    return x * x
print('Square of 178:', square_178(178))
# %%
# Cell 180
def square_179(x):
    return x * x
print('Square of 179:', square_179(179))
# %%
# Cell 181
def square_180(x):
    return x * x
print('Square of 180:', square_180(180))
# %%
# Cell 182
def square_181(x):
    return x * x
print('Square of 181:', square_181(181))
# %%
# Cell 183
def square_182(x):
    return x * x
print('Square of 182:', square_182(182))
# %%
# Cell 184
def square_183(x):
    return x * x
print('Square of 183:', square_183(183))
# %%
# Cell 185
def square_184(x):
    return x * x
print('Square of 184:', square_184(184))
# %%
# Cell 186
def square_185(x):
    return x * x
print('Square of 185:', square_185(185))
# %%
# Cell 187
def square_186(x):
    return x * x
print('Square of 186:', square_186(186))
# %%
# Cell 188
def square_187(x):
    return x * x
print('Square of 187:', square_187(187))
# %%
# Cell 189
def square_188(x):
    return x * x
print('Square of 188:', square_188(188))
# %%
# Cell 190
def square_189(x):
    return x * x
print('Square of 189:', square_189(189))
# %%
# Cell 191
def square_190(x):
    return x * x
print('Square of 190:', square_190(190))
# %%
# Cell 192
def square_191(x):
    return x * x
print('Square of 191:', square_191(191))
# %%
# Cell 193
def square_192(x):
    return x * x
print('Square of 192:', square_192(192))
# %%
# Cell 194
def square_193(x):
    return x * x
print('Square of 193:', square_193(193))
# %%
# Cell 195
def square_194(x):
    return x * x
print('Square of 194:', square_194(194))
# %%
# Cell 196
def square_195(x):
    return x * x
print('Square of 195:', square_195(195))
# %%
# Cell 197
def square_196(x):
    return x * x
print('Square of 196:', square_196(196))
# %%
# Cell 198
def square_197(x):
    return x * x
print('Square of 197:', square_197(197))
# %%
# Cell 199
def square_198(x):
    return x * x
print('Square of 198:', square_198(198))
# %%
# Cell 200
def square_199(x):
    return x * x
print('Square of 199:', square_199(199))
